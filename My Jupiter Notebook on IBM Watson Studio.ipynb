# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jiangduo Chen**
# <br>Fairy Queen

# %% [markdown]
# *I am interested in data science becuase it validates the philosophy of casuality.*

# %% [markdown]
# ### The following code tests the Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# ![IMG_8350.JPG](attachment:IMG_8350.JPG)
#
# https://www.linkedin.com/in/jiangduochen/
#
# **2022 Reading List**
# -  The Horde: How the Mongols Changed the World by Marie Favereau
# -  Clean Craftsmanship by Robert C Martin
# -  Causality by Judea Pearl
